# %% [markdown]
# Number类型

# %%
type(1)
# Out:
# int

# %%
type(1.111)
# Out:
# float

# %%
type(1+1.1)
# Out:
# float

# %%
type(1+1.0)
# Out:
# float

# %%
type(1*1.0)
# Out:
# float

# %%
type(2/2)#一定是float
# Out:
# float

# %%
type(2//2)#取商不取余or向下取整
# Out:
# int

# %%
1//2
# Out:
# 0

# %% [markdown]
# 十进制、八进制、二进制、十六进制

# %% [markdown]
# 二进制

# %%
type(0b10)
# Out:
# int

# %%
0b10
# Out:
# 2

# %% [markdown]
# 八进制

# %%
0o11
# Out:
# 9

# %% [markdown]
# 十六进制

# %%
0x20
# Out:
# 32

# %% [markdown]
# 进制转换

# %%
bin(10)#2进制
# Out:
# '0b1010'

# %%
bin(0x10)
# Out:
# '0b10000'

# %%
int(0b10000)#10进制
# Out:
# 16

# %%
hex(0o777)#16进制
# Out:
# '0x1ff'

# %%
oct(0b111)#8进制
# Out:
# '0o7'

# %% [markdown]
# Bool类型
